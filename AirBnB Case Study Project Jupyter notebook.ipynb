# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:172: RuntimeWarning: divide by zero encountered in exp2
#   eps=exp2(ld(-112)),
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:51: RuntimeWarning: divide by zero encountered in log10
#   self.precision = int(-log10(self.eps))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:52: RuntimeWarning: divide by zero encountered in power
#   self.resolution = float_to_float(float_conv(10) ** (-self.precision))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:184: RuntimeWarning: divide by zero encountered in exp2
#   epsneg_f80 = exp2(ld(-64))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:185: RuntimeWarning: divide by zero encountered in exp2
#   tiny_f80 = exp2(ld(-16382))
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\getlimits.py:199: RuntimeWarning: divide by zero encountered in exp2
#   eps=exp2(ld(-63)),
# ...

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb.head()
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
neighbourhood = air_bnb.groupby('neighbourhood_group')['neighbourhood'].count().reset_index()
neighbourhood
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:844: RuntimeWarning: divide by zero encountered in not_equal
#   mask = (ids != -1) & ~isna(val)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:844: RuntimeWarning: divide by zero encountered in invert
#   mask = (ids != -1) & ~isna(val)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:844: RuntimeWarning: divide by zero encountered in bitwise_and
#   mask = (ids != -1) & ~isna(val)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\numeric.py:2453: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
# ...

# %%
# Are private rooms the most popular in manhattan?

# first filter our data_frame - aka only manhattan
# then groupby
# then aggregate (are we summing, counting, averaging)
# then select specific columns

rooms = air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan'].groupby(['room_type']).count()[['id']]
rooms
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:284: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in greater_equal
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in less
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# ...

# %%
# Which hosts are the busiest and based on their reviews?

num_reviews = air_bnb.groupby('host_name')['number_of_reviews'].count().reset_index().sort_values('number_of_reviews', ascending=False)
num_reviews
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\algorithms.py:769: RuntimeWarning: divide by zero encountered in equal
#   code_is_na = codes == na_sentinel
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:844: RuntimeWarning: divide by zero encountered in not_equal
#   mask = (ids != -1) & ~isna(val)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:844: RuntimeWarning: divide by zero encountered in invert
#   mask = (ids != -1) & ~isna(val)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:844: RuntimeWarning: divide by zero encountered in bitwise_and
#   mask = (ids != -1) & ~isna(val)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\numeric.py:2453: RuntimeWarning: divide by zero encountered in equal
# ...

# %%
#Which neighorhood group has the highest average price?

hprice = air_bnb.groupby('neighbourhood_group')['price'].mean().reset_index().sort_values('price', ascending=False)
hprice
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\algorithms.py:769: RuntimeWarning: divide by zero encountered in equal
#   code_is_na = codes == na_sentinel
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\sorting.py:396: RuntimeWarning: divide by zero encountered in invert
#   non_nans = items[~mask]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\sorting.py:397: RuntimeWarning: divide by zero encountered in invert
#   non_nan_idx = idx[~mask]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:284: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# ...

# %%
# Which neighbor hood group has the highest total price?

highprice = air_bnb.groupby('price').count().sort_values('price', ascending=False)
highprice
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6015: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\algorithms.py:769: RuntimeWarning: divide by zero encountered in equal
#   code_is_na = codes == na_sentinel
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1731: RuntimeWarning: divide by zero encountered in not_equal
#   mask = ids != -1
# ...

# %%
#Which top 5 hosts have the highest total price?

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
#noavail = air_bnb.groupby('host_name', 'availability_365')['number_of_reviews'].sum(>100).reset_index().sort_values('availability_365', ascending=True)
#noavail
#noavail = air_bnb[air_bnb.number_of_reviews>= 100].groupby(['availability_365']).count()('availability_365', ascending=False)
#noavail

noavail = air_bnb.groupby('host_name', 'availability_365')['number_of_reviews'].sum().reset_index()
noavail = noavail[noavail['availability_365'] >= 100].sort_values('availability_365', ascending=True)
noavail
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     542         try:
# --> 543             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     544         except KeyError:
#
# KeyError: 'availability_365'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-e09c18f86ca0> in <module>
#       3 #noavail
#       4
# ----> 5 noavail = air_bnb.groupby('host_name', 'availability_365')['number_of_reviews'].sum().reset_index()
#       6 noavail = noavail[noavail['availability_365'] >= 100].sort_values('availability_365', ascending=True)
#       7 noavail
#
# ...

# %%
# What host has the highest total of prices and where are they located?

# %%
# When did Danielle from Queens last receive a review?

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %% [markdown]
# 2. How many listings have completely open availability?

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
